# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(42)
X=2*np.random.rand(100,1)
y=4+3*X+np.random.randn(100,1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
model=LinearRegression().fit(X_train,y_train)
model
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([[8.37667405],
#        [4.4343875 ],
#        [8.88822722],
#        [4.2219342 ],
#        [8.15788612],
#        [4.4928011 ],
#        [5.187277  ],
#        [5.81265465],
#        [6.7107956 ],
#        [9.48137727],
#        [4.76014778],
#        [8.39818985],
#        [8.54894985],
#        [8.14458516],
#        [4.6244171 ],
#        [5.11006349],
#        [4.94943452],
#        [4.19500304],
#        [9.57775922],
#        [7.55239963],
#        [8.02463294],
#        [7.41092008],
#        [9.21560809],
#        [7.63183085],
#        [5.64527429],
#        [5.52186322],
#        [4.74653362],
#        [8.14124839],
#        [9.36607367],
#        [7.46464653]])

# %%
print("coef",round(model.coef_[0][0],2))
print("Intercept",round(model.intercept_[0],2))
print("Mean Squared Error",round(mean_squared_error(y_test,y_pred),2))
# Out:
# coef 2.79
# Intercept 4.08
# Mean Squared Error 1.09

# %%
plt.scatter(X_test,y_test,color='blue',label='Actual')
plt.plot(X_test,y_pred,color='red',label='predction')
plt.xlabel("Feature (X)")
plt.ylabel("Target(y)")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()

# %%
print("""
This graph shows a simple linear regression model.
- Blue dots represent the actual data points.
- The red line represents the predicted regression line.
- The upward slope indicates a positive relationship between X and Y.
- As the feature (X) increases, the target value (Y) also increases.
- The line fits the data reasonably well, showing a good linear trend.
""")
# Out:
# This graph shows a simple linear regression model.
# - Blue dots represent the actual data points.
# - The red line represents the predicted regression line.
# - The upward slope indicates a positive relationship between X and Y.
# - As the feature (X) increases, the target value (Y) also increases.
# - The line fits the data reasonably well, showing a good linear trend.
