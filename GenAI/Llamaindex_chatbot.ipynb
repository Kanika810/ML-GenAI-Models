# %% [markdown]
# **Building a chatbot with LangChain**

# %%
# !pip install -U -q llama-index llama-index-llms-groq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 97.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.7/333.7 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 102.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 11.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %%
import os
from llama_index.core.llms import ChatMessage, MessageRole
from llama_index.llms.groq import Groq

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
llm = Groq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
def chat():
    history = [
        ChatMessage(role=MessageRole.SYSTEM, content="You are a helpful assistant. Be concise and accurate.")
    ]

    print("LlamaIndex Chatbot. Type 'exit' to quit.\n")

    while True:
        user_input = input("You: ").strip()
        if user_input.lower() in {"exit", "quit"}:
            break

        # add user message
        history.append(ChatMessage(role=MessageRole.USER, content=user_input))

        # call LLM with full history
        resp = llm.chat(messages=history)  # ChatResponse
        answer = resp.message.content

        print(f"Bot: {answer}\n")

        # add assistant message
        history.append(ChatMessage(role=MessageRole.ASSISTANT, content=answer))

        print("-"*80)

# %%
chat()
# Out:
# LlamaIndex Chatbot. Type 'exit' to quit.
#
# You: explain deep learning
# Bot: **Deep Learning Overview**
# ==========================
#
# Deep learning is a subset of machine learning that uses artificial neural networks to analyze and interpret data. It's inspired by the structure and function of the human brain, with layers of interconnected nodes (neurons) that process and transform inputs.
#
# **Key Components**
# ----------------
#
# 1. **Artificial Neural Networks (ANNs)**: Composed of layers of interconnected nodes (neurons) that process inputs.
# 2. **Layers**: Multiple layers, including input, hidden, and output layers, that allow the network to learn complex patterns.
# 3. **Activation Functions**: Introduce non-linearity to the network, enabling it to learn and represent more complex relationships.
# 4. **Backpropagation**: An algorithm used to train the network by minimizing the error between predicted and actual outputs.
#
# **Deep Learning Techniques**
# -------------------------
#
# 1. **Convolutional Neural Networks (CNNs)**: Used for image and video processing, CNNs apply filters to extract features.
# 2. **Recurrent Neural Networks (RNNs)**: Suitable for sequential data, RNNs use feedback connections to capture temporal relationships.
# 3. **Long Short-Term Memory (LSTM) Networks**: A type of RNN that uses memory cells to learn long-term dependencies.
#
# **Applications**
# ---------------
#
# 1. **Computer Vision**: Image classification, object detection, segmentation, and generation.
# 2. **Natural Language Processing (NLP)**: Text classification, sentiment analysis, language translation, and text generation.
# 3. **Speech Recognition**: Speech-to-text systems that use deep learning to recognize spoken words and phrases.
#
# **Advantages**
# ------------
#
# 1. **Improved Accuracy**: Deep learning models can achieve state-of-the-art performance in various tasks.
# 2. **Automated Feature Learning**: Deep learning models can learn relevant features from raw data, reducing the need for manual feature engineering.
# 3. **Flexibility**: Deep learning models can be applied to a wide range of tasks and domains.
#
# --------------------------------------------------------------------------------
# You: exit
